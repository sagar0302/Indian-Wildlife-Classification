# %%
# !python train_cnn_svm_resnet50_final.py
# Out:
# Scanning training data for class weights...
# Found 1661 images belonging to 20 classes.
# Found 1661 images belonging to 20 classes.
# Found 429 images belonging to 20 classes.
#
# Starting CNN Training...
# Epoch 1/25
#
#   1/104 ==================== 24:54 15s/step - accuracy: 0.0000e+00 - loss: 4.3851
#   2/104 ==================== 2:06 1s/step - accuracy: 0.0156 - loss: 4.3837
#   3/104 ==================== 2:24 1s/step - accuracy: 0.0451 - loss: 4.2863
#   4/104 ==================== 2:30 2s/step - accuracy: 0.0612 - loss: 4.1878
#   5/104 ==================== 2:51 2s/step - accuracy: 0.0690 - loss: 4.1571
#   6/104 ==================== 2:44 2s/step - accuracy: 0.0783 - loss: 4.1252
#   7/104 ==================== 2:40 2s/step - accuracy: 0.0875 - loss: 4.0939
#   8/104 ==================== 2:39 2s/step - accuracy: 0.0922 - loss: 4.0745
#   9/104 ==================== 2:38 2s/step - accuracy: 0.0966 - loss: 4.0496
# ...

# %%
# !streamlit run streamlit_2.py
